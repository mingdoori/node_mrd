# %% [markdown]
# <a href="https://colab.research.google.com/github/mingdoori/node_mrd/blob/main/test02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = '최요원'
age = 30

# %%
# 자동완성 : 시작하는 문자 몇 개 + tab
